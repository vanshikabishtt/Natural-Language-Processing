# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\ananconda\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\ananconda\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\ananconda\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\ananconda\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\ananconda\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\ananconda\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\ananconda\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\ananconda\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\ananconda\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\ananconda\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\ananconda\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\ananconda\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\ananconda\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\ananconda\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\ananconda\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\ananconda\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\ananconda\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\ananconda\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\ananconda\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\ananconda\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\ananconda\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\ananconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\ananconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\ananconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\ananconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\ananconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ananconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ananconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\ananconda\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\ananconda\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\ananconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\ananconda\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\ananconda\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\ananconda\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\ananconda\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\ananconda\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\ananconda\lib\site-packages (from jinja2->spacy) (3.0.2)

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.8/12.8 MB 2.2 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 3.2 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.2 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.8 MB 2.9 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 2.8 MB/s eta 0:00:03
#      ------------------ --------------------- 5.8/12.8 MB 3.0 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.4 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 3.6 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 3.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.8 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# Test with a sample text
doc = nlp("Hello, spaCy is successfully installed!")
print([token.text for token in doc])
# Out:
# ['Hello', ',', 'spaCy', 'is', 'successfully', 'installed', '!']

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.1.3

# %%
print(spacy.__version__)
# Out:
# 3.8.7
