# %%
#Perform standard imports:
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
#Print the set og spaCy's default stop words
print(nlp.Defaults.stop_words)
# Out:
# {'perhaps', 'never', 'whereafter', 'hereby', 'these', 'besides', 'one', 'used', 'everyone', 'else', 'becoming', 'must', 'ten', 'beforehand', 'together', 'while', 'mostly', 'yet', 'hereafter', 'less', 'this', 'always', 'empty', 'make', 'through', 'otherwise', 'as', 'back', '‘m', 'out', 'least', 'noone', 'put', 'into', 'there', 'before', 'have', 'between', 'move', 'after', 'whole', 'an', "'m", "n't", 'down', 'n‘t', 'six', 'sometime', 'where', 'no', 'themselves', 'every', 'using', 'wherever', 'am', 'seems', 'towards', 'you', '‘d', 'itself', 'now', 'next', 'third', 'call', 'fifteen', 'serious', 'former', 'due', 'various', 'meanwhile', 'will', 'very', 'i', 'everywhere', 'go', 'sixty', 'hers', 'or', 'their', 'can', 'cannot', 'others', 'say', 'herein', 'show', 'almost', 'amongst', 'whose', 'give', 'if', 'bottom', 'whom', "'re", "'ve", 'were', 'against', 'of', 'rather', 'me', 'get', 'whereupon', 'nobody', 'only', 'someone', 'whoever', 'most', 'part', 'whither', 'however', "'s", 'him', 'four', 'us', 'ca', 'just', 'a', 'around', 'last', 'himself', 'unless', 'along', 'did', 'anyway', 'other', 'become', 'that', 'than', 'my', 'are', "'d", '’m', 'doing', 'beyond', 'thereupon', 'behind', 'should', 'above', '’ll', 'take', 'being', 'across', 'our', 'seem', 'moreover', 'much', 'among', 'somehow', 'side', 'front', 'therefore', 'under', 'something', 'therein', 'please', 'at', 'anywhere', 'none', 'here', 'twenty', 'toward', 'latter', 'for', 'might', 'eight', 'is', 'five', 'well', 'few', 'fifty', 'though', 'indeed', 'because', 'nine', 'two', 'anyone', 'could', 'during', '‘s', 'whenever', 'be', '’s', 'up', 'by', 'so', 'since', 'those', 'sometimes', 'then', 'not', 'regarding', 'done', 'any', 'many', 'her', 'see', 'hence', 'three', 're', 'first', 'off', 'and', 'thereby', 'n’t', 'all', 'the', 'been', 'does', 'nevertheless', 'often', 'beside', 'why', 'yourself', 'has', 'already', 'some', 'everything', 'name', 'about', 'via', 'we', 'forty', 'do', 'same', 'but', 'them', 'another', 'still', '’re', 'whereas', 'top', 'his', 'they', 'your', 'such', 'formerly', 'wherein', 'made', 'would', 'ourselves', 'became', 'ever', 'from', 'whereby', 'hereupon', 'namely', 'quite', 'seeming', 'several', 'too', 'below', 'yours', 'except', 'although', "'ll", 'mine', 'over', 'anyhow', 'becomes', 'hundred', 'somewhere', '’d', 'elsewhere', 'in', 'thru', 'which', 'seemed', 'on', 'when', 'both', 'once', 'yourselves', '‘re', 'she', 'was', 'herself', 'really', 'more', 'myself', 'even', 'he', 'anything', 'whether', 'thus', 'latterly', 'what', '‘ve', 'enough', 'per', '‘ll', 'neither', 'keep', 'alone', 'who', 'it', 'each', 'eleven', 'whatever', 'ours', '’ve', 'further', 'with', 'had', 'full', 'until', 'nothing', 'either', 'to', 'how', 'thence', 'within', 'nowhere', 'own', 'thereafter', 'onto', 'also', 'upon', 'throughout', 'again', 'amount', 'twelve', 'without', 'may', 'whence', 'afterwards', 'nor', 'its'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# ## To see if a word is a stop word or not

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# ## To add a stop word

# %%
#Add the word to the set of stop words. Use lowercase
nlp.Defaults.stop_words.add('btw')

#Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# ## To remove a stop word

# %%
# Remove the word from the set of stop_words
nlp.Defaults.stop_words.remove('beyond')

# %%
#Remove th stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326
