# %% [markdown]
# ## NLTK stand for Natural Language Toolkit

# %% [markdown]
# ### import Libraries

# %%
import nltk
from nltk import word_tokenize

# %% [markdown]
# ### NLTK is an open source library. It porvides many functionalities and include pre-trained model.

# %% [markdown]
# ## NLTK Language Model

# %%
nltk.download('punkt_tab')     #It is a pre-trained model for toknization
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\MAYANK
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %% [markdown]
# ## Perform Tokenizationn

# %%
sentence = "Today is Friday. Next Week, We're coming from U.S.!"

# %%
sen2= "We're here to help you! ask the question, email support@bcnet.ax or visit us at http://www.abcnet.ax!"

# %%
for token in word_tokenize(sentence):
    print(token)
# Out:
# Today
# is
# Friday
# .
# Next
# Week
# ,
# We
# 're
# coming
# from
# U.S.
# !

# %%
sentence.split()
# Out:
# ['Today', 'is', 'Friday.', 'Next', 'Week,', "We're", 'coming', 'from', 'U.S.!']

# %%
sen3= "We are learning NLP. This is a good course. Is weather good today?"

# %%
for token in word_tokenize(sen3):
    print(token)
# Out:
# We
# are
# learning
# NLP
# .
# This
# is
# a
# good
# course
# .
# Is
# weather
# good
# today
# ?
