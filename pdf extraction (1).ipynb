# %%
pip install PyMuPdf

# %%
import fitz  

doc = fitz.open(r"C:\Users\Asus\OneDrive\Desktop\Accent-HCi-Gen-2018.pdf")  

for page in doc:
    print(page.get_text())

# %%
first = doc.load_page(1)
print(f'First page is -------{first.get_text()}')

# %%
Second= doc.load_page(2)
print(f'Second page is -------{Second.get_text()}')

# %%
new_pdf=fitz.open()

# %%
new_pdf.insert_pdf(doc,from_page=1,to_page=1)
new_pdf.insert_pdf(doc,from_page=2,to_page=2)

# %%
new_pdf.save(r"C:\Users\Asus\OneDrive\Desktop\Extracted.pdf")
new_pdf.close()
doc.close()

print("New PDF with selected pages has been created.")
