# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
#Creates a Doc object
doc=nlp(u'Tesla is looking at buying U.S. startup for $6 million')

# %%
#Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
doc2= nlp(u"Tesla isn't     looking into startups anymore.")
for token in doc2:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2
# Out:
# Tesla isn't     looking into startups anymore.

# %%
doc2[0]
# Out:
# Tesla

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %% [markdown]
# #### to see the full name of tag use spacy.explain(tag)

# %%
spacy.explain("PROPN")
# Out:
# 'proper noun'

# %%
spacy.explain("nsubj")
# Out:
# 'nominal subject'

# %%
#text (the original word)
doc2[4].text
# Out:
# 'looking'

# %%
#Lemmas (the base form of the word)
doc2[4].lemma_
# Out:
# 'look'

# %%
#pos (Part of speech)
doc2[4].pos_
# Out:
# 'VERB'

# %%
doc2[4].tag_
# Out:
# 'VBG'

# %%
doc2[4].shape_
# Out:
# 'xxxx'

# %%
doc2[4].is_alpha
# Out:
# True

# %%
doc2= nlp(u"Tesla isn't     looking into startups anymore.")
doc2[4].is_stop
# Out:
# False

# %%
#Simple parts of speech and detailed tags
print(doc2[4].pos_)
print(doc2[4].tag_ + ' / ' + spacy.explain(doc2[4].tag_))
# Out:
# VERB
# VBG / verb, gerund or present participle

# %%
#Word Shapes:
print(doc2[0].text+' : '+doc2[0].shape_)
print(doc2[5].text+' : '+doc[5].shape_)
# Out:
# Tesla : Xxxxx
# into : X.X.

# %%
#is_alpha:
print(doc2[0].text+' : '+doc2[0].is_alpha)
print(doc2[5].text+' : '+doc[5].is_alpha)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #is_alpha:
# ----> 2 print(doc2[0].text+' : '+doc2[0].is_alpha)
#       3 print(doc2[5].text+' : '+doc[5].is_alpha)
#
# TypeError: can only concatenate str (not "bool") to str

# %%
print(doc2[5].text+' : '+doc[5].is_stop)

# %%
doc3=nlp(u'Although commonly attributed to John Lennon from his song "Beautiful Boy", \ the phrase "Life is what happens to us while we are making other plans" was written by \
cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')

# %%
life_quote=doc3[16:30]
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# ### Sentences

# %%
doc4=nlp(u'This is the first sentence. This is another sentence. This is the last sentence')

# %%
doc4[0:8]
# Out:
# This is the first sentence. This is

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
#If the sentence is starting with the given iter then it will give True
doc4[6].is_sent_start
# Out:
# True
